# %%
import numpy as np
import pandas as pd
import ee
import geemap
import os
import glob

# %%
ee.Authenticate()
ee.Initialize(project = "ee-algae")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# load cci lake points
# assign a 5km buffer --> ERA5-Land pixel size
cci_lakes = ee.FeatureCollection("projects/ee-sarice/assets/CCI_Lakes").map(lambda img: img.buffer(5 * 1000))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# CCI lake ids
cci_lake_ids = cci_lakes.aggregate_array("CCI ID").getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Terra starts from 2002-07-04
years = list(range(2003, 2024))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
out_dir = "/mnt/Data_2tb/laketemp_bias/modis_cloud/raw"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# function from https://spatialthoughts.com/2021/08/19/qa-bands-bitmasks-gee/
def bitwiseExtract(inputBit,
                  fromBit,
                  toBit):
    maskSize = ee.Number(1).add(toBit).subtract(fromBit)
    mask = ee.Number(1).leftShift(maskSize).subtract(1)
    return inputBit.rightShift(fromBit).bitwiseAnd(mask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# def extract_cloud_qc_flag(img):
#     # extract bit from 0-1 (data quality) and 6-7 (average error)
#     # Bits 0-1: 0: clear, 1: cloudy, 2: mixed, 3: not set, assumed clear
#     qc_img = bitwiseExtract(img.select("state_1km"), 0, 1).rename("qcflag")
#     # remove the bit bands
#     return qc_img

def extract_cloud_mask(img):
    # extract bit from 0-1 (data quality) and 6-7 (average error)
    # Bits 0-1: 0: clear, 1: cloudy, 2: mixed, 3: not set, assumed clear
    total = img.select("sur_refl_b01").multiply(0).add(1).rename("total")
    cloudmask = bitwiseExtract(img.select("state_1km"), 0, 1).eq(1).rename("cloud")
    
    output_mask = total.addBands(cloudmask)
    # remove the bit bands
    return output_mask
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for yr in years:
    # Load MODIS Terra and Aqua
    # terra = ee.ImageCollection("MODIS/061/MOD09GA").filterDate(f"{yr}-01-01", f"{yr+1}-01-01")
    aqua = ee.ImageCollection("MODIS/061/MYD09GA").filterDate(f"{yr}-01-01", f"{yr+1}-01-01")
    
    # extract cloud mask
    # terra_cloud_mask = terra.map(extract_cloud_mask)
    aqua_cloud_mask = aqua.map(extract_cloud_mask)
    
    # extract the count of cloudy pixel
    geemap.zonal_statistics(aqua_cloud_mask.toBands(),
                            cci_lakes,
                            f"{out_dir}/{yr}_aqua_cloud.csv",
                            statistics_type='SUM',
                            scale = 1000,
                           )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/531fa8d8bf71c484e30cead5094a93a7-e00718a6f6a9d48656be2d6a6b9d0cea:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2003_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/6ee1d8a51b7a7fcd10014e98817d8b91-72b8e7eb0db410b2a33afbc946c02d76:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2004_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/03bf50ae6760b1bbf49476ece517c8b3-e7426d34b47ac16fd5433b413a50b062:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2005_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/d492099ba84d50e721fe459862bec009-22f6ae3505d71f4ff2456e3046f4f93f:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2006_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/d42ec153c30ad85f8b64e50d3864e9f2-5fcf51f1eeea0f9c001ea00093f37aca:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2007_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/cdfb3f8f8bd40faf1b3510446a91af9a-07b3510133bdaa514ac80aa31bc53fa4:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2008_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/51df9939b17895e8742fac34c4756bf8-47d46938964126422f8e902ba6a5e076:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2009_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/459c2886d62483912eca459ad671b090-092fb1783bb0d81bf37d9c21d4745164:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2010_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/420d025368844acb0131f5f25ff996d1-c019df161960befc950f9e13805a2381:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2011_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/22c1951aa36632d78b83334d3cc7c439-7b5877647ef1adaf5deaba1a8adf486b:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2012_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/f96adbd09b9f8d9ee2f180e8f7d8cd22-49272301d698792cc010f30ce2218c6d:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2013_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/ecd0449592cb161855fd1ee7b158a1b8-64a73c8663ad7f65f74627c7392d9326:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2014_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/90bc83c0c7dc78ebc50f5ecd9971b7f9-88a6eb4a7bb218b65edc206e32ad948d:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2015_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/e5c682039d56fe26e58241c5d4683b7e-4a435e5cc25dee60e12a4784a2a122c0:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2016_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/303e866a2dfadad8ed897e58c14727a4-e32d7d927bb5f3f5d797d7d32f512b5f:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2017_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/a3fd947ef0d7500ac36d8767aa4f91f0-98bade7c5bdbcba270231610ca2d9a99:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2018_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/919db080bd894075afff6ab59b45769b-95618f5517d1304519308a9719f7f6ea:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2019_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/8cce497d92e905626b32263ba76cd0fc-8b18b92a84671e940520f1a3308c13a8:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2020_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/9ef284eac524ed39fbb1d25a173fd804-fcad054c54754f6e28cc52665065d605:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2021_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/895541aae8e41b44462b9ecf029bc06d-0a08e3ab1ce26437a86add89690a3bf1:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2022_aqua_cloud.csv
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-algae/tables/dc1edd69780829abf064aaf6f07da08c-709c18c42215932c633d7e168f2a3d49:getFeatures
# Please wait ...
# Data downloaded to /mnt/Data_2tb/laketemp_bias/modis_cloud/raw/2023_aqua_cloud.csv

# %%
water_temp_df = pd.read_csv("/nas/cee-hydro/laketemp_bias/era5land/water_temp.csv", index_col=0, parse_dates=True)

# %%
# keep the non-cloudy observations
temp_df = water_temp_df.mask(cloud_cover_df, np.nan)
temp_df.loc[pd.date_range("2020-07-01", "2020-07-31"), "62"]
# Out:
# 2020-07-01          NaN
# 2020-07-02          NaN
# 2020-07-03          NaN
# 2020-07-04    10.918571
# 2020-07-05          NaN
# 2020-07-06          NaN
# 2020-07-07          NaN
# 2020-07-08          NaN
# 2020-07-09          NaN
# 2020-07-10    10.666950
# 2020-07-11    11.385794
# 2020-07-12          NaN
# 2020-07-13    12.507469
# 2020-07-14    13.122165
# 2020-07-15          NaN
# 2020-07-16    13.381817
# 2020-07-17    14.801996
# 2020-07-18    14.255700
# 2020-07-19          NaN
# 2020-07-20          NaN
# 2020-07-21          NaN
# 2020-07-22          NaN
# 2020-07-23          NaN
# 2020-07-24          NaN
# 2020-07-25          NaN
# 2020-07-26    14.268321
# 2020-07-27    13.085286
# 2020-07-28    14.051697
# 2020-07-29    13.128550
# 2020-07-30          NaN
# 2020-07-31          NaN
# Name: 62, dtype: float64

# %%
water_temp_df_cloud = water_temp_df.mask(cloud_cover_df, np.nan)
water_temp_df_cloud.to_csv("/nas/cee-hydro/laketemp_bias/era5land/water_temp_cloud.csv")

# %%
water_temp_df_cloud
# Out:
#                   799      3114      7889      2516     12262      1519  3053  \
# 2000-01-01        NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 2000-01-02        NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 2000-01-03        NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 2000-01-04        NaN       NaN       NaN       NaN       NaN       NaN   NaN
# 2000-01-05        NaN       NaN       NaN       NaN       NaN       NaN   NaN
# ...               ...       ...       ...       ...       ...       ...   ...
# 2023-12-27  15.396758       NaN       NaN       NaN       NaN       NaN   NaN
# 2023-12-28        NaN       NaN  6.700112       NaN       NaN  7.396017   NaN
# 2023-12-29        NaN  3.617657       NaN  4.023334       NaN  6.898298   NaN
# 2023-12-30  15.608841       NaN  5.829605       NaN       NaN       NaN   NaN
# 2023-12-31        NaN       NaN       NaN       NaN  2.593807  6.401340   NaN
#
#                 1203      3350       3607  ...  300000430       278  293  \
# 2000-01-01       NaN       NaN        NaN  ...        NaN       NaN  NaN
# 2000-01-02       NaN       NaN        NaN  ...        NaN       NaN  NaN
# 2000-01-03       NaN       NaN        NaN  ...        NaN       NaN  NaN
# 2000-01-04       NaN       NaN        NaN  ...        NaN       NaN  NaN
# 2000-01-05       NaN       NaN        NaN  ...        NaN       NaN  NaN
# ...              ...       ...        ...  ...        ...       ...  ...
# 2023-12-27  4.061035  3.459507  21.349592  ...  -0.000342       NaN  NaN
# 2023-12-28  4.053041  3.504207  21.951714  ...  -0.000342  6.988318  NaN
# 2023-12-29  3.977074  4.106709  22.446399  ...  -0.000342       NaN  NaN
# 2023-12-30  3.873746       NaN  22.942908  ...        NaN  7.067787  NaN
# 2023-12-31       NaN       NaN  23.497687  ...  -0.000342  7.025704  NaN
#
#             300000771       378  473       309  141       212  170
# 2000-01-01        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# 2000-01-02        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# 2000-01-03        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# 2000-01-04        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# 2000-01-05        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# ...               ...       ...  ...       ...  ...       ...  ...
# 2023-12-27        NaN       NaN  NaN       NaN  NaN       NaN  NaN
# 2023-12-28        NaN  2.999573  NaN  0.752726  NaN -0.000342  NaN
# 2023-12-29        NaN  2.998324  NaN  0.720556  NaN -0.000342  NaN
# 2023-12-30        NaN       NaN  NaN       NaN  NaN -0.000342  NaN
# 2023-12-31   0.828416  2.898258  NaN  0.650813  NaN -0.000342  NaN
#
# [8766 rows x 2016 columns]
