# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import geopandas as gpd
import dask.dataframe as dd

# %%
# %matplotlib widget

# %%
# directory saved simulated temperature
obs_full_path = "/nas/cee-hydro/laketemp_bias/era5land/water_temp.csv"
obs_cloud_path = "/nas/cee-hydro/laketemp_bias/era5land/water_temp_cloud.csv"
a2w_full_dir = "/nas/cee-hydro/laketemp_bias/simulations/a2w_full_sim"
a2w_cloud_dir = "/nas/cee-hydro/laketemp_bias/simulations/a2w_cloud_sim"


# lstm simulations with 0 clamped
lstm_full_dir_clamp_0 = "/nas/cee-hydro/laketemp_bias/simulations/lstm_full_sim"
lstm_cloud_dir_clamp_0 = "/nas/cee-hydro/laketemp_bias/simulations/lstm_cloud_sim"


# lstm simulations without 0 clamped
lstm_full_dir = "/nas/cee-hydro/laketemp_bias/simulations/lstm_full_sim_backup"
lstm_cloud_dir = "/nas/cee-hydro/laketemp_bias/simulations/lstm_cloud_sim_backup"

# %%
# load cci lakes
cci_lake_list = pd.read_csv("../data/cci_lakes_hydrolake_depth.csv")["CCI ID"].to_numpy()
cci_lakes = pd.read_csv("../data/ESA_CCI_static_lake_mask_v2_1km_UoR_metadata_fv2.1_06Oct2021_4laketemp.csv", index_col=0).loc[cci_lake_list]
cci_lakes_gdf = gpd.GeoDataFrame(cci_lakes, geometry=gpd.points_from_xy(cci_lakes['LON CENTRE'], cci_lakes['LAT CENTRE']),
                                crs="epsg:4326")
cci_lakes_gdf.head()
# Out:
#                     NAME                        COUNTRY  LAT CENTRE  \
# CCI ID
# 799      Hawizeh marshes  Iraq;Iran Islamic Republic of     31.3792
# 3114           loch Ness                 United Kingdom     57.3792
# 7889        lough Melvin         Ireland;United Kingdom     54.4208
# 2516         loch Lomond                 United Kingdom     56.0708
# 12262         loch Leven                 United Kingdom     56.2042
#
#         LON CENTRE  MAX DISTANCE TO LAND (KM)  LAT MIN BOX  LAT MAX BOX  \
# CCI ID
# 799        47.7236                        1.0      31.2042      31.4292
# 3114       -4.3597                        1.2      57.1042      57.4542
# 7889       -8.1264                        1.3      54.3625      54.4958
# 2516       -4.5792                        1.5      55.9708      56.3458
# 12262      -3.3792                        1.5      56.1375      56.2625
#
#         LON MIN BOX  LON MAX BOX ID in GLOBOLAKES 1000 MASK ID in CGLOPS MASK  \
# CCI ID
# 799         47.6042      47.7792                       799;              799;
# 3114        -4.7125      -4.2958                      3114;               NaN
# 7889        -8.2875      -8.0542                      7889;               NaN
# 2516        -4.7542      -4.4792                      2516;               NaN
# 12262       -3.4542      -3.2958                     12262;               NaN
#
#                          geometry
# CCI ID
# 799     POINT (47.72360 31.37920)
# 3114    POINT (-4.35970 57.37920)
# 7889    POINT (-8.12640 54.42080)
# 2516    POINT (-4.57920 56.07080)
# 12262   POINT (-3.37920 56.20420)

# %% [markdown]
# # Case 1

# %%
test_lake_id = "733"
lake_name = cci_lakes_gdf.loc[int(test_lake_id), "NAME"] + ", " + cci_lakes_gdf.loc[int(test_lake_id), "COUNTRY"]
# lake_name = "Changdang lake, China"
a2w_full_sim = pd.read_csv(f"{a2w_full_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)
a2w_cloud_sim = pd.read_csv(f"{a2w_cloud_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)

lstm_full_sim_clamp_0 = pd.read_csv(f"{lstm_full_dir_clamp_0}/{test_lake_id}.csv", index_col=0, parse_dates=True)
lstm_cloud_sim_clamp_0 = pd.read_csv(f"{lstm_cloud_dir_clamp_0}/{test_lake_id}.csv", index_col=0, parse_dates=True)

lstm_full_sim = pd.read_csv(f"{lstm_full_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)
lstm_cloud_sim = pd.read_csv(f"{lstm_cloud_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)

obs_full = pd.read_csv(obs_full_path, index_col=0, parse_dates=True).loc[:, test_lake_id]
obs_cloud = pd.read_csv(obs_cloud_path, index_col=0, parse_dates=True).loc[:, test_lake_id]

fig, axes = plt.subplots(1, 2, figsize = (12, 4), sharex = "row")
date_range = pd.date_range("2003-01-01", "2008-12-31")
# Define figure labels
# fig_labels = [["(a1)", "(a2)"], ["(b1)", "(b2)"], ["(c1)", "(c2)"]]

# First: Time series of observations
sns.lineplot(obs_full.loc[date_range], label="Daily-LSWT", ax=axes[0], color="tab:blue")
sns.scatterplot(obs_cloud.loc[date_range], label="Sat-LSWT", ax=axes[0], color="orange")
axes[0].set_xlabel("Date")
axes[0].set_title(f"(a) Synthetic observations")
axes[0].set_ylabel("LSWT (°C)")
axes[0].legend()

# Time series of LSTM simulations
sns.lineplot(lstm_full_sim.mean(axis=1).loc[date_range], label="LSTM-Daily-LSWT", ax=axes[1], color="tab:blue")
sns.lineplot(lstm_cloud_sim.mean(axis=1).loc[date_range], label="LSTM-Sat-LSWT", ax=axes[1], color="orange")
axes[1].set_xlabel("Date")
axes[1].set_title(f"(b) LSTM simulations")
axes[1].set_ylabel("LSWT (°C)")
axes[1].legend()


sns.lineplot(lstm_full_sim_clamp_0.mean(axis=1).loc[date_range], 
             label="LSTM-Daily-LSWT; Clamp 0", 
             ax=axes[1], 
             color="tab:blue", linestyle = "--")
sns.lineplot(lstm_cloud_sim_clamp_0.mean(axis=1).loc[date_range], 
             label="LSTM-Sat-LSWT; Clamp 0", 
             ax=axes[1], 
             color="orange", 
             linestyle = "--")

axes[1].legend()

# Figure title
#fig.suptitle(f"{lake_name}, CCI_id = {test_lake_id}")
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lake_name
# Out:
# ' Kiskitto lake, Canada'

# %% [markdown]
# # Case 2

# %%
test_lake_id = "44"
lake_name = cci_lakes_gdf.loc[int(test_lake_id), "NAME"] + ", " + cci_lakes_gdf.loc[int(test_lake_id), "COUNTRY"]
# lake_name = "Changdang lake, China"
a2w_full_sim = pd.read_csv(f"{a2w_full_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)
a2w_cloud_sim = pd.read_csv(f"{a2w_cloud_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)

lstm_full_sim_clamp_0 = pd.read_csv(f"{lstm_full_dir_clamp_0}/{test_lake_id}.csv", index_col=0, parse_dates=True)
lstm_cloud_sim_clamp_0 = pd.read_csv(f"{lstm_cloud_dir_clamp_0}/{test_lake_id}.csv", index_col=0, parse_dates=True)

lstm_full_sim = pd.read_csv(f"{lstm_full_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)
lstm_cloud_sim = pd.read_csv(f"{lstm_cloud_dir}/{test_lake_id}.csv", index_col=0, parse_dates=True)

obs_full = pd.read_csv(obs_full_path, index_col=0, parse_dates=True).loc[:, test_lake_id]
obs_cloud = pd.read_csv(obs_cloud_path, index_col=0, parse_dates=True).loc[:, test_lake_id]

fig, axes = plt.subplots(1, 2, figsize = (12, 4), sharex = "row")
date_range = pd.date_range("2003-01-01", "2008-12-31")
# Define figure labels
# fig_labels = [["(a1)", "(a2)"], ["(b1)", "(b2)"], ["(c1)", "(c2)"]]

# First: Time series of observations
sns.lineplot(obs_full.loc[date_range], label="Daily-LSWT", ax=axes[0], color="tab:blue")
sns.scatterplot(obs_cloud.loc[date_range], label="Sat-LSWT", ax=axes[0], color="orange")
axes[0].set_xlabel("Date")
axes[0].set_title(f"(a) Synthetic observations")
axes[0].set_ylabel("LSWT (°C)")
axes[0].legend()

# Time series of LSTM simulations
sns.lineplot(lstm_full_sim.mean(axis=1).loc[date_range], label="LSTM-Daily-LSWT", ax=axes[1], color="tab:blue")
sns.lineplot(lstm_cloud_sim.mean(axis=1).loc[date_range], label="LSTM-Sat-LSWT", ax=axes[1], color="orange")
axes[1].set_xlabel("Date")
axes[1].set_title(f"(b) LSTM simulations")
axes[1].set_ylabel("LSWT (°C)")
axes[1].legend()


sns.lineplot(lstm_full_sim_clamp_0.mean(axis=1).loc[date_range], 
             label="LSTM-Daily-LSWT; Clamp 0", 
             ax=axes[1], 
             color="tab:blue", linestyle = "--")
sns.lineplot(lstm_cloud_sim_clamp_0.mean(axis=1).loc[date_range], 
             label="LSTM-Sat-LSWT; Clamp 0", 
             ax=axes[1], 
             color="orange", 
             linestyle = "--")

axes[1].legend()

# Figure title
#fig.suptitle(f"{lake_name}, CCI_id = {test_lake_id}")
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lake_name
# Out:
# ' lake of the Woods, United States;Canada'
